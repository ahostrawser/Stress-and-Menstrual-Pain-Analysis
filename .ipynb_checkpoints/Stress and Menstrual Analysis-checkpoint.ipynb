# %% [markdown]
# # Investigate Menstrual data set

# %% [markdown]
# ### Data source: Menstrual Health & Productivity Dataset
# Link: https://www.kaggle.com/datasets/puspitachowdhury2/menstrual-health-dataset/data

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor

from scipy import stats
from scipy.stats import spearmanr

np.random.seed(42)

# %% [markdown]
# ## Wrangle period log dataset

# %% [markdown]
# Load datasets and check for cleaniness

# %% [markdown]
# ### Load and investigate data

# %%
period_log_df = pd.read_csv('Period_Log.csv')
period_log_df.head()
# Out:
#   user_id  cycle_number  start_date  cycle_length_days  prev_cycle_length  \
# 0  U00001             1  2024-02-13                 33                NaN
# 1  U00001             2  2024-03-17                 33               33.0
# 2  U00001             3  2024-04-19                 34               33.0
# 3  U00001             4  2024-05-23                 31               34.0
# 4  U00001             5  2024-06-23                 31               31.0
#
#   cycle_phase flow_level  pain_level pms_symptoms  mood_score  ...  \
# 0      Luteal      Heavy           9          Yes           6  ...
# 1  Follicular      Light           2           No           8  ...
# 2  Follicular      Heavy           8           No           5  ...
# 3      Luteal      Light           3           No           8  ...
# 4      Luteal   Moderate           3           No           9  ...
#
#    sleep_hours_cycle  energy_level  concentration_score  work_hours_lost  \
# 0                5.3             6                    7              5.1
# 1                4.6             7                    8              2.6
# 2                5.1             5                    5              6.8
# 3                6.7             8                    8              2.5
# 4                5.8             9                    8              2.4
#
#    estrogen_pgml  progesterone_ngml  ovulation_result overall_health_score  \
# 0           84.7               4.14          Positive                  6.5
# 1          126.1               2.79          Negative                  9.4
# 2          131.1               1.70          Negative                  6.7
# 3           82.0               8.50          Negative                  9.0
# 4           55.5               6.30          Negative                  9.3
#
#    log_consistency_score  prepared_before_period
# 0                  0.949                       0
# 1                  0.949                       1
# 2                  0.949                       1
# 3                  0.949                       0
# 4                  0.949                       1
#
# [5 rows x 21 columns]

# %%
period_log_df.shape
# Out:
# (17976, 21)

# %%
period_log_df.describe()
# Out:
#        cycle_number  cycle_length_days  prev_cycle_length    pain_level  \
# count  17976.000000       17976.000000       15976.000000  17976.000000
# mean       5.214842          27.816756          27.826865      4.854473
# std        2.931241           2.400329           2.399832      2.230292
# min        1.000000          22.000000          22.000000      1.000000
# 25%        3.000000          26.000000          26.000000      3.000000
# 50%        5.000000          28.000000          28.000000      5.000000
# 75%        7.000000          29.000000          29.000000      6.000000
# max       12.000000          44.000000          44.000000     10.000000
#
#          mood_score  stress_score_cycle  sleep_hours_cycle  energy_level  \
# count  17976.000000        17976.000000       17976.000000  17976.000000
# mean       7.084947            5.749260           6.960253      6.832165
# std        1.506431            1.771953           1.315146      1.687533
# min        1.000000            1.000000           4.500000      1.000000
# 25%        6.000000            4.500000           6.000000      6.000000
# 50%        7.000000            5.800000           7.000000      7.000000
# 75%        8.000000            7.000000           7.900000      8.000000
# max       10.000000           10.000000          10.000000     10.000000
#
#        concentration_score  work_hours_lost  estrogen_pgml  progesterone_ngml  \
# count         17976.000000     17976.000000   17976.000000       17976.000000
# mean              7.352025         3.394443      96.429840           5.336521
# std               1.435035         1.495181      27.928743           3.791151
# min               2.000000         0.000000      10.000000           0.100000
# 25%               6.000000         2.300000      76.300000           2.230000
# 50%               7.000000         3.400000      94.300000           3.830000
# 75%               8.000000         4.400000     115.100000           8.370000
# max              10.000000         8.800000     206.500000          20.250000
#
#        overall_health_score  log_consistency_score  prepared_before_period
# count          17976.000000           17976.000000            17976.000000
# mean               8.548665               0.935288                0.567701
# std                1.106405               0.020129                0.495409
# min                4.400000               0.860000                0.000000
# 25%                7.800000               0.921000                0.000000
# 50%                8.600000               0.936000                1.000000
# 75%                9.500000               0.950000                1.000000
# max               10.000000               0.985000                1.000000

# %%
period_log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17976 entries, 0 to 17975
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 17976 non-null  object
#  1   cycle_number            17976 non-null  int64
#  2   start_date              17976 non-null  object
#  3   cycle_length_days       17976 non-null  int64
#  4   prev_cycle_length       15976 non-null  float64
#  5   cycle_phase             17976 non-null  object
#  6   flow_level              17976 non-null  object
#  7   pain_level              17976 non-null  int64
#  8   pms_symptoms            17976 non-null  object
#  9   mood_score              17976 non-null  int64
#  10  stress_score_cycle      17976 non-null  float64
#  11  sleep_hours_cycle       17976 non-null  float64
#  12  energy_level            17976 non-null  int64
#  13  concentration_score     17976 non-null  int64
#  14  work_hours_lost         17976 non-null  float64
#  15  estrogen_pgml           17976 non-null  float64
#  16  progesterone_ngml       17976 non-null  float64
#  17  ovulation_result        17976 non-null  object
#  18  overall_health_score    17976 non-null  float64
#  19  log_consistency_score   17976 non-null  float64
#  20  prepared_before_period  17976 non-null  int64
# dtypes: float64(8), int64(7), object(6)
# memory usage: 2.9+ MB

# %%
#convert start date column to date
period_log_df['start_date'] = pd.to_datetime(period_log_df['start_date'])
#confirm conversion
period_log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17976 entries, 0 to 17975
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 17976 non-null  object
#  1   cycle_number            17976 non-null  int64
#  2   start_date              17976 non-null  datetime64[ns]
#  3   cycle_length_days       17976 non-null  int64
#  4   prev_cycle_length       15976 non-null  float64
#  5   cycle_phase             17976 non-null  object
#  6   flow_level              17976 non-null  object
#  7   pain_level              17976 non-null  int64
#  8   pms_symptoms            17976 non-null  object
#  9   mood_score              17976 non-null  int64
#  10  stress_score_cycle      17976 non-null  float64
#  11  sleep_hours_cycle       17976 non-null  float64
#  12  energy_level            17976 non-null  int64
#  13  concentration_score     17976 non-null  int64
#  14  work_hours_lost         17976 non-null  float64
#  15  estrogen_pgml           17976 non-null  float64
#  16  progesterone_ngml       17976 non-null  float64
#  17  ovulation_result        17976 non-null  object
#  18  overall_health_score    17976 non-null  float64
#  19  log_consistency_score   17976 non-null  float64
#  20  prepared_before_period  17976 non-null  int64
# dtypes: datetime64[ns](1), float64(8), int64(7), object(5)
# memory usage: 2.9+ MB

# %%
#check for duplicates
duplicates = period_log_df[period_log_df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [user_id, cycle_number, start_date, cycle_length_days, prev_cycle_length, cycle_phase, flow_level, pain_level, pms_symptoms, mood_score, stress_score_cycle, sleep_hours_cycle, energy_level, concentration_score, work_hours_lost, estrogen_pgml, progesterone_ngml, ovulation_result, overall_health_score, log_consistency_score, prepared_before_period]
# Index: []
#
# [0 rows x 21 columns]

# %%
#count of null values by column
period_log_df.isnull().sum()
# Out:
# user_id                      0
# cycle_number                 0
# start_date                   0
# cycle_length_days            0
# prev_cycle_length         2000
# cycle_phase                  0
# flow_level                   0
# pain_level                   0
# pms_symptoms                 0
# mood_score                   0
# stress_score_cycle           0
# sleep_hours_cycle            0
# energy_level                 0
# concentration_score          0
# work_hours_lost              0
# estrogen_pgml                0
# progesterone_ngml            0
# ovulation_result             0
# overall_health_score         0
# log_consistency_score        0
# prepared_before_period       0
# dtype: int64

# %%
filtered_period_log_df = period_log_df[period_log_df['prev_cycle_length'].isnull()]
filtered_period_log_df.head()
# Out:
#    user_id  cycle_number start_date  cycle_length_days  prev_cycle_length  \
# 0   U00001             1 2024-02-13                 33                NaN
# 11  U00002             1 2024-03-13                 25                NaN
# 23  U00003             1 2024-03-15                 26                NaN
# 34  U00004             1 2024-02-01                 28                NaN
# 45  U00005             1 2024-03-23                 36                NaN
#
#    cycle_phase flow_level  pain_level pms_symptoms  mood_score  ...  \
# 0       Luteal      Heavy           9          Yes           6  ...
# 11  Follicular      Light           2           No           9  ...
# 23   Menstrual   Moderate           4           No           8  ...
# 34  Follicular      Light           3           No           9  ...
# 45  Follicular   Moderate           5           No           6  ...
#
#     sleep_hours_cycle  energy_level  concentration_score  work_hours_lost  \
# 0                 5.3             6                    7              5.1
# 11                5.6             8                    9              2.6
# 23                7.3             7                    9              2.5
# 34                7.1             6                    8              2.7
# 45                7.6            10                    7              2.0
#
#     estrogen_pgml  progesterone_ngml  ovulation_result overall_health_score  \
# 0            84.7               4.14          Positive                  6.5
# 11           63.9               3.44          Positive                  9.6
# 23           27.4               1.47          Negative                  8.9
# 34          107.6               1.20          Negative                  9.5
# 45          104.7               2.58          Negative                  8.9
#
#     log_consistency_score  prepared_before_period
# 0                   0.949                       0
# 11                  0.923                       0
# 23                  0.953                       0
# 34                  0.946                       0
# 45                  0.929                       0
#
# [5 rows x 21 columns]

# %%
#check if any of that the rows with na prev cycle length has the cycle number of 1
filtered_period_log_df = filtered_period_log_df[filtered_period_log_df['cycle_number'] != 1]
filtered_period_log_df.head()
# Out:
# Empty DataFrame
# Columns: [user_id, cycle_number, start_date, cycle_length_days, prev_cycle_length, cycle_phase, flow_level, pain_level, pms_symptoms, mood_score, stress_score_cycle, sleep_hours_cycle, energy_level, concentration_score, work_hours_lost, estrogen_pgml, progesterone_ngml, ovulation_result, overall_health_score, log_consistency_score, prepared_before_period]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Categorical

# %% [markdown]
# #### Cycle Phase

# %%
#identify values in column
cycle_phase = period_log_df[['cycle_phase']].copy()
group_cycle_phase = cycle_phase.groupby('cycle_phase').size()
group_cycle_phase.head()
# Out:
# cycle_phase
# Follicular    8092
# Luteal        8068
# Menstrual     1816
# dtype: int64

# %%
#no ordinal data
#one hot encode
period_log_df = pd.get_dummies(period_log_df, columns=['cycle_phase'], dtype=int)
period_log_df.head()
# Out:
#   user_id  cycle_number start_date  cycle_length_days  prev_cycle_length  \
# 0  U00001             1 2024-02-13                 33                NaN
# 1  U00001             2 2024-03-17                 33               33.0
# 2  U00001             3 2024-04-19                 34               33.0
# 3  U00001             4 2024-05-23                 31               34.0
# 4  U00001             5 2024-06-23                 31               31.0
#
#   flow_level  pain_level pms_symptoms  mood_score  stress_score_cycle  ...  \
# 0      Heavy           9          Yes           6                 5.4  ...
# 1      Light           2           No           8                 3.7  ...
# 2      Heavy           8           No           5                 5.7  ...
# 3      Light           3           No           8                 5.2  ...
# 4   Moderate           3           No           9                 3.7  ...
#
#    work_hours_lost  estrogen_pgml  progesterone_ngml  ovulation_result  \
# 0              5.1           84.7               4.14          Positive
# 1              2.6          126.1               2.79          Negative
# 2              6.8          131.1               1.70          Negative
# 3              2.5           82.0               8.50          Negative
# 4              2.4           55.5               6.30          Negative
#
#    overall_health_score  log_consistency_score prepared_before_period  \
# 0                   6.5                  0.949                      0
# 1                   9.4                  0.949                      1
# 2                   6.7                  0.949                      1
# 3                   9.0                  0.949                      0
# 4                   9.3                  0.949                      1
#
#    cycle_phase_Follicular  cycle_phase_Luteal  cycle_phase_Menstrual
# 0                       0                   1                      0
# 1                       1                   0                      0
# 2                       1                   0                      0
# 3                       0                   1                      0
# 4                       0                   1                      0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Flow level

# %%
#identify values in column
flow_level = period_log_df[['flow_level']].copy()
group_flow_level = flow_level.groupby('flow_level').size()
group_flow_level.head()
# Out:
# flow_level
# Heavy       2454
# Light       6665
# Moderate    8857
# dtype: int64

# %%
#ordinal data
#create order for values
flow_level_order = {'Light': 0, 'Moderate': 1, 'Heavy': 2}
#map to identified order
period_log_df['flow_level'] = period_log_df['flow_level'].map(flow_level_order)
period_log_df.head()
# Out:
#   user_id  cycle_number start_date  cycle_length_days  prev_cycle_length  \
# 0  U00001             1 2024-02-13                 33                NaN
# 1  U00001             2 2024-03-17                 33               33.0
# 2  U00001             3 2024-04-19                 34               33.0
# 3  U00001             4 2024-05-23                 31               34.0
# 4  U00001             5 2024-06-23                 31               31.0
#
#    flow_level  pain_level pms_symptoms  mood_score  stress_score_cycle  ...  \
# 0           2           9          Yes           6                 5.4  ...
# 1           0           2           No           8                 3.7  ...
# 2           2           8           No           5                 5.7  ...
# 3           0           3           No           8                 5.2  ...
# 4           1           3           No           9                 3.7  ...
#
#    work_hours_lost  estrogen_pgml  progesterone_ngml  ovulation_result  \
# 0              5.1           84.7               4.14          Positive
# 1              2.6          126.1               2.79          Negative
# 2              6.8          131.1               1.70          Negative
# 3              2.5           82.0               8.50          Negative
# 4              2.4           55.5               6.30          Negative
#
#    overall_health_score  log_consistency_score prepared_before_period  \
# 0                   6.5                  0.949                      0
# 1                   9.4                  0.949                      1
# 2                   6.7                  0.949                      1
# 3                   9.0                  0.949                      0
# 4                   9.3                  0.949                      1
#
#    cycle_phase_Follicular  cycle_phase_Luteal  cycle_phase_Menstrual
# 0                       0                   1                      0
# 1                       1                   0                      0
# 2                       1                   0                      0
# 3                       0                   1                      0
# 4                       0                   1                      0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### PMS Symptoms

# %%
#identify values in column
pms_symptoms = period_log_df[['pms_symptoms']].copy()
group_pms_symptoms = pms_symptoms.groupby('pms_symptoms').size()
group_pms_symptoms.head()
# Out:
# pms_symptoms
# No     12675
# Yes     5301
# dtype: int64

# %%
#convert PMS symptoms to numerical
period_log_df['pms_symptoms'] = period_log_df['pms_symptoms'].map({'Yes': 1, 'No': 0})
period_log_df.head()
# Out:
#   user_id  cycle_number start_date  cycle_length_days  prev_cycle_length  \
# 0  U00001             1 2024-02-13                 33                NaN
# 1  U00001             2 2024-03-17                 33               33.0
# 2  U00001             3 2024-04-19                 34               33.0
# 3  U00001             4 2024-05-23                 31               34.0
# 4  U00001             5 2024-06-23                 31               31.0
#
#    flow_level  pain_level  pms_symptoms  mood_score  stress_score_cycle  ...  \
# 0           2           9             1           6                 5.4  ...
# 1           0           2             0           8                 3.7  ...
# 2           2           8             0           5                 5.7  ...
# 3           0           3             0           8                 5.2  ...
# 4           1           3             0           9                 3.7  ...
#
#    work_hours_lost  estrogen_pgml  progesterone_ngml  ovulation_result  \
# 0              5.1           84.7               4.14          Positive
# 1              2.6          126.1               2.79          Negative
# 2              6.8          131.1               1.70          Negative
# 3              2.5           82.0               8.50          Negative
# 4              2.4           55.5               6.30          Negative
#
#    overall_health_score  log_consistency_score prepared_before_period  \
# 0                   6.5                  0.949                      0
# 1                   9.4                  0.949                      1
# 2                   6.7                  0.949                      1
# 3                   9.0                  0.949                      0
# 4                   9.3                  0.949                      1
#
#    cycle_phase_Follicular  cycle_phase_Luteal  cycle_phase_Menstrual
# 0                       0                   1                      0
# 1                       1                   0                      0
# 2                       1                   0                      0
# 3                       0                   1                      0
# 4                       0                   1                      0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Ovulation Result

# %%
#identify values in column
ovulation_result = period_log_df[['ovulation_result']].copy()
group_ovulation_result = ovulation_result.groupby('ovulation_result').size()
group_ovulation_result.head()
# Out:
# ovulation_result
# Negative    8246
# Positive    9730
# dtype: int64

# %%
#convert ovulation result to numerical
period_log_df['x'] = period_log_df['ovulation_result'].map({'Positive': 1, 'Negative': 0})
period_log_df.head()
# Out:
#   user_id  cycle_number start_date  cycle_length_days  prev_cycle_length  \
# 0  U00001             1 2024-02-13                 33                NaN
# 1  U00001             2 2024-03-17                 33               33.0
# 2  U00001             3 2024-04-19                 34               33.0
# 3  U00001             4 2024-05-23                 31               34.0
# 4  U00001             5 2024-06-23                 31               31.0
#
#    flow_level  pain_level  pms_symptoms  mood_score  stress_score_cycle  ...  \
# 0           2           9             1           6                 5.4  ...
# 1           0           2             0           8                 3.7  ...
# 2           2           8             0           5                 5.7  ...
# 3           0           3             0           8                 5.2  ...
# 4           1           3             0           9                 3.7  ...
#
#    estrogen_pgml  progesterone_ngml  ovulation_result  overall_health_score  \
# 0           84.7               4.14          Positive                   6.5
# 1          126.1               2.79          Negative                   9.4
# 2          131.1               1.70          Negative                   6.7
# 3           82.0               8.50          Negative                   9.0
# 4           55.5               6.30          Negative                   9.3
#
#    log_consistency_score  prepared_before_period cycle_phase_Follicular  \
# 0                  0.949                       0                      0
# 1                  0.949                       1                      1
# 2                  0.949                       1                      1
# 3                  0.949                       0                      0
# 4                  0.949                       1                      0
#
#    cycle_phase_Luteal  cycle_phase_Menstrual  x
# 0                   1                      0  1
# 1                   0                      0  0
# 2                   0                      0  0
# 3                   1                      0  0
# 4                   1                      0  0
#
# [5 rows x 24 columns]

# %%
#identify values in column
cycle_number = period_log_df[['cycle_number']].copy()
group_cycle_number = cycle_number.groupby('cycle_number').size()
group_cycle_number
# Out:
# cycle_number
# 1     2000
# 2     2000
# 3     2000
# 4     2000
# 5     2000
# 6     2000
# 7     1721
# 8     1431
# 9     1129
# 10     847
# 11     560
# 12     288
# dtype: int64

# %% [markdown]
# ### Cycle

# %% [markdown]
# Since this is longitudinal data, I will create a dataset filtered to one cycle for analysis to ensure that participants arent duplicated in the sampling and statistical tests

# %%
period_log_df = period_log_df.query('cycle_number == 3')
period_log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 2 to 17968
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 2000 non-null   object
#  1   cycle_number            2000 non-null   int64
#  2   start_date              2000 non-null   datetime64[ns]
#  3   cycle_length_days       2000 non-null   int64
#  4   prev_cycle_length       2000 non-null   float64
#  5   flow_level              2000 non-null   int64
#  6   pain_level              2000 non-null   int64
#  7   pms_symptoms            2000 non-null   int64
#  8   mood_score              2000 non-null   int64
#  9   stress_score_cycle      2000 non-null   float64
#  10  sleep_hours_cycle       2000 non-null   float64
#  11  energy_level            2000 non-null   int64
#  12  concentration_score     2000 non-null   int64
#  13  work_hours_lost         2000 non-null   float64
#  14  estrogen_pgml           2000 non-null   float64
#  15  progesterone_ngml       2000 non-null   float64
#  16  ovulation_result        2000 non-null   object
#  17  overall_health_score    2000 non-null   float64
#  18  log_consistency_score   2000 non-null   float64
#  19  prepared_before_period  2000 non-null   int64
#  20  cycle_phase_Follicular  2000 non-null   int64
#  21  cycle_phase_Luteal      2000 non-null   int64
#  22  cycle_phase_Menstrual   2000 non-null   int64
#  23  x                       2000 non-null   int64
# dtypes: datetime64[ns](1), float64(8), int64(13), object(2)
# memory usage: 390.6+ KB

# %% [markdown]
# ### High and low stress datasets

# %% [markdown]
# I will create high and low stress datasets for analysis

# %%
period_log_df.describe()
# Out:
#        cycle_number           start_date  cycle_length_days  \
# count        2000.0                 2000        2000.000000
# mean            3.0  2024-04-08 07:30:00          27.783000
# min             3.0  2024-02-19 00:00:00          22.000000
# 25%             3.0  2024-03-15 00:00:00          26.000000
# 50%             3.0  2024-04-08 00:00:00          28.000000
# 75%             3.0  2024-05-01 06:00:00          29.000000
# max             3.0  2024-06-04 00:00:00          42.000000
# std             0.0                  NaN           2.373126
#
#        prev_cycle_length   flow_level   pain_level  pms_symptoms   mood_score  \
# count        2000.000000  2000.000000  2000.000000   2000.000000  2000.000000
# mean           27.781500     0.767500     4.922000      0.292500     7.065500
# min            22.000000     0.000000     1.000000      0.000000     2.000000
# 25%            26.000000     0.000000     3.000000      0.000000     6.000000
# 50%            28.000000     1.000000     5.000000      0.000000     7.000000
# 75%            29.000000     1.000000     7.000000      1.000000     8.000000
# max            40.000000     2.000000    10.000000      1.000000    10.000000
# std             2.354258     0.669827     2.243754      0.455024     1.540583
#
#        stress_score_cycle  sleep_hours_cycle  ...  work_hours_lost  \
# count          2000.00000        2000.000000  ...      2000.000000
# mean              5.78660           6.960050  ...         3.430200
# min               1.00000           4.500000  ...         0.000000
# 25%               4.50000           6.100000  ...         2.400000
# 50%               5.80000           7.000000  ...         3.400000
# 75%               7.10000           7.900000  ...         4.500000
# max              10.00000          10.000000  ...         8.800000
# std               1.79523           1.302255  ...         1.512667
#
#        estrogen_pgml  progesterone_ngml  overall_health_score  \
# count    2000.000000        2000.000000           2000.000000
# mean       95.347700           5.392120              8.522550
# min        23.700000           0.100000              4.400000
# 25%        74.400000           2.180000              7.700000
# 50%        93.250000           3.860000              8.600000
# 75%       113.300000           8.362500              9.500000
# max       197.500000          19.230000             10.000000
# std        28.483861           3.857293              1.126682
#
#        log_consistency_score  prepared_before_period  cycle_phase_Follicular  \
# count            2000.000000             2000.000000             2000.000000
# mean                0.935474                0.654000                0.429000
# min                 0.860000                0.000000                0.000000
# 25%                 0.921000                0.000000                0.000000
# 50%                 0.937000                1.000000                0.000000
# 75%                 0.951000                1.000000                1.000000
# max                 0.985000                1.000000                1.000000
# std                 0.020575                0.475812                0.495057
#
#        cycle_phase_Luteal  cycle_phase_Menstrual            x
# count         2000.000000            2000.000000  2000.000000
# mean             0.459500               0.111500     0.525000
# min              0.000000               0.000000     0.000000
# 25%              0.000000               0.000000     0.000000
# 50%              0.000000               0.000000     1.000000
# 75%              1.000000               0.000000     1.000000
# max              1.000000               1.000000     1.000000
# std              0.498482               0.314829     0.499499
#
# [8 rows x 22 columns]

# %% [markdown]
# #### High Stress

# %%
#split the data for high stress (using the top 25%)
high_stress = period_log_df.query('stress_score_cycle >= 7.100000')

# %%
high_stress_mean = high_stress.mean(numeric_only=True)
high_stress_mean
# Out:
# cycle_number               3.000000
# cycle_length_days         27.880716
# prev_cycle_length         27.793241
# flow_level                 0.793241
# pain_level                 6.755467
# pms_symptoms               0.395626
# mood_score                 6.035785
# stress_score_cycle         8.073956
# sleep_hours_cycle          6.611730
# energy_level               5.363817
# concentration_score        6.037773
# work_hours_lost            4.839165
# estrogen_pgml             94.793837
# progesterone_ngml          6.008588
# overall_health_score       7.329026
# log_consistency_score      0.935447
# prepared_before_period     0.656064
# cycle_phase_Follicular     0.361829
# cycle_phase_Luteal         0.548708
# cycle_phase_Menstrual      0.089463
# x                          0.542744
# dtype: float64

# %% [markdown]
# #### Low Stress

# %%
#split the data for low stress (using the bottom 25%)
low_stress = period_log_df.query('stress_score_cycle <= 4.500000')

# %%
low_stress_mean = low_stress.mean(numeric_only=True)
low_stress_mean
# Out:
# cycle_number               3.000000
# cycle_length_days         27.715706
# prev_cycle_length         27.866799
# flow_level                 0.759443
# pain_level                 3.145129
# pms_symptoms               0.166998
# mood_score                 8.192843
# stress_score_cycle         3.473757
# sleep_hours_cycle          7.298012
# energy_level               8.172962
# concentration_score        8.504970
# work_hours_lost            2.009145
# estrogen_pgml             95.038171
# progesterone_ngml          4.740775
# overall_health_score       9.599602
# log_consistency_score      0.935487
# prepared_before_period     0.666004
# cycle_phase_Follicular     0.504970
# cycle_phase_Luteal         0.365805
# cycle_phase_Menstrual      0.129225
# x                          0.512922
# dtype: float64

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# #### Stress Differences

# %% [markdown]
# ##### High vs Low Stress Diff

# %% [markdown]
# Check the difference in means between high and low stress datasets

# %%
difference = high_stress_mean - low_stress_mean
difference
# Out:
# cycle_number              0.000000
# cycle_length_days         0.165010
# prev_cycle_length        -0.073559
# flow_level                0.033797
# pain_level                3.610338
# pms_symptoms              0.228628
# mood_score               -2.157058
# stress_score_cycle        4.600199
# sleep_hours_cycle        -0.686282
# energy_level             -2.809145
# concentration_score      -2.467197
# work_hours_lost           2.830020
# estrogen_pgml            -0.244334
# progesterone_ngml         1.267813
# overall_health_score     -2.270577
# log_consistency_score    -0.000040
# prepared_before_period   -0.009940
# cycle_phase_Follicular   -0.143141
# cycle_phase_Luteal        0.182903
# cycle_phase_Menstrual    -0.039761
# x                         0.029821
# dtype: float64

# %% [markdown]
# Looking at the difference in means from high stress to low stress, we see that on average, the pain level and work hours lost is higher. Additionally, for high stress, we see a lower average mood score, energy level, concentration score, estrogen_pgml, and overall health score

# %% [markdown]
# #### Drop unnecessary columns

# %%
period_log_df = period_log_df.drop(['cycle_number', 'cycle_length_days', 'prev_cycle_length', 'sleep_hours_cycle', 'progesterone_ngml', 'log_consistency_score', 'prepared_before_period', 'start_date', 'flow_level', 'pms_symptoms', 'ovulation_result', 'cycle_phase_Follicular', 'cycle_phase_Luteal', 'cycle_phase_Menstrual'], axis=1)

# %%
period_log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 2 to 17968
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               2000 non-null   object
#  1   pain_level            2000 non-null   int64
#  2   mood_score            2000 non-null   int64
#  3   stress_score_cycle    2000 non-null   float64
#  4   energy_level          2000 non-null   int64
#  5   concentration_score   2000 non-null   int64
#  6   work_hours_lost       2000 non-null   float64
#  7   estrogen_pgml         2000 non-null   float64
#  8   overall_health_score  2000 non-null   float64
#  9   x                     2000 non-null   int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 171.9+ KB

# %%
period_log_df.describe()
# Out:
#         pain_level   mood_score  stress_score_cycle  energy_level  \
# count  2000.000000  2000.000000          2000.00000   2000.000000
# mean      4.922000     7.065500             5.78660      6.762500
# std       2.243754     1.540583             1.79523      1.687162
# min       1.000000     2.000000             1.00000      1.000000
# 25%       3.000000     6.000000             4.50000      6.000000
# 50%       5.000000     7.000000             5.80000      7.000000
# 75%       7.000000     8.000000             7.10000      8.000000
# max      10.000000    10.000000            10.00000     10.000000
#
#        concentration_score  work_hours_lost  estrogen_pgml  \
# count          2000.000000      2000.000000    2000.000000
# mean              7.296000         3.430200      95.347700
# std               1.456518         1.512667      28.483861
# min               2.000000         0.000000      23.700000
# 25%               6.000000         2.400000      74.400000
# 50%               7.000000         3.400000      93.250000
# 75%               8.000000         4.500000     113.300000
# max              10.000000         8.800000     197.500000
#
#        overall_health_score            x
# count           2000.000000  2000.000000
# mean               8.522550     0.525000
# std                1.126682     0.499499
# min                4.400000     0.000000
# 25%                7.700000     0.000000
# 50%                8.600000     1.000000
# 75%                9.500000     1.000000
# max               10.000000     1.000000

# %% [markdown]
# #### Confidence Interval

# %% [markdown]
# What is the difference in the mean pain_level for those with high stress scores vs low stress scores?
# Is there evidence of a difference in the average pain_level?

# %% [markdown]
# I will build a confidence interval for the diffence of average pain_level for those with high stress and low stress.

# %%
#create a sample with replacement
bootsamp = period_log_df.sample(200, replace = True)

# %%
h_stress = bootsamp.query('stress_score_cycle >= 7.100000')
h_stress.stress_score_cycle.count()
# Out:
# np.int64(56)

# %%
h_stress_proportion = h_stress.stress_score_cycle.count()/bootsamp.stress_score_cycle.count()
h_stress_proportion
# Out:
# np.float64(0.28)

# %%
l_stress = bootsamp.query('stress_score_cycle <= 4.500000')
l_stress.stress_score_cycle.count()
# Out:
# np.int64(45)

# %%
l_stress_proportion = l_stress.stress_score_cycle.count()/bootsamp.stress_score_cycle.count()
l_stress_proportion
# Out:
# np.float64(0.225)

# %%
h_stress.pain_level.mean()
# Out:
# np.float64(6.392857142857143)

# %%
l_stress.pain_level.mean()
# Out:
# np.float64(3.3333333333333335)

# %%
bootsamp.pain_level.mean()
# Out:
# np.float64(4.855)

# %%
period_log_df.pain_level.mean()
# Out:
# np.float64(4.922)

# %%
bootsamp['stress_score_cycle'].mean()
# Out:
# np.float64(5.7525)

# %%
#bootstrap to create confidence intervals
l_stress__pain_means, h_stress_pain_means, diffs, sample_means = [], [], [], []
for _ in range(10000):
    bootsamp = period_log_df.sample(200, replace = True)
    h_stress_pain_mean = bootsamp[bootsamp['stress_score_cycle'] >= 7.000000]['pain_level'].mean()
    l_stress__pain_mean = bootsamp[bootsamp['stress_score_cycle'] <= 4.500000]['pain_level'].mean()
    #append the info
    l_stress__pain_means.append(l_stress__pain_mean)
    h_stress_pain_means.append(h_stress_pain_mean)
    diffs.append(h_stress_pain_mean - l_stress__pain_mean)
    sample_means.append(bootsamp.pain_level.mean())

# %%
#identify low and high
low, high = np.percentile(diffs, 2.5), np.percentile(diffs, 97.5)
low, high
# Out:
# (np.float64(2.8549211958646525), np.float64(4.245285965957837))

# %%
#plot the difference between means
plt.figure(figsize=(8, 4))
plt.hist(diffs, alpha = 0.5);
plt.axvline(x=low, color='r', linewidth=1);
plt.axvline(x=high, color='r', linewidth=1);

# %% [markdown]
# The interval was built at a 95% confidence level, and since the difference did not contain zero, this suggests there is truly a difference in the average pain_level in the population of those with high stress scores as compared to those with low stress scores.

# %%
plt.figure(figsize=(8, 4))
plt.hist(l_stress__pain_means, alpha = 0.5);
plt.hist(h_stress_pain_means, alpha = 0.5);

# %% [markdown]
# #### T-test

# %%
t_statistic, p_value = stats.ttest_ind(high_stress['pain_level'], low_stress['pain_level'])

# %%
t_statistic
# Out:
# np.float64(32.38946281936324)

# %%
p_value
# Out:
# np.float64(3.883418800229247e-158)

# %% [markdown]
# #### Correlation

# %%
plt.figure(figsize=(7, 4))
plt.scatter(period_log_df['stress_score_cycle'], period_log_df['pain_level']);
plt.xlabel('stress_score_cycle');
plt.ylabel('pain_level');

# %%
correlation_coefficient, p_value = spearmanr(period_log_df['stress_score_cycle'], period_log_df['pain_level'])
print(f"Spearman's r: {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Spearman's r: 0.6040161207217352
# P-value: 3.576931573172372e-199

# %% [markdown]
# #### Linear Regression

# %%
period_log_df['intercept'] = 1

# %%
lm = sm.OLS(period_log_df['pain_level'], period_log_df[['intercept', 'stress_score_cycle']])
results_lm = lm.fit()
results_lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             pain_level   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     1173.
# Date:                Thu, 04 Dec 2025   Prob (F-statistic):          1.20e-202
# Time:                        18:05:04   Log-Likelihood:                -3991.8
# No. Observations:                2000   AIC:                             7988.
# Df Residuals:                    1998   BIC:                             7999.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# intercept              0.5234      0.134      3.892      0.000       0.260       0.787
# stress_score_cycle     0.7601      0.022     34.248      0.000       0.717       0.804
# ==============================================================================
# Omnibus:                       37.857   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.638
# Skew:                           0.298   Prob(JB):                     1.11e-08
# Kurtosis:                       2.710   Cond. No.                         21.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# I have completed the anayslis for the scope of this project
